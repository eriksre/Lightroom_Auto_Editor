# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('lightroom_edits.parquet')

# %%
# identify images with no edits

constant_columns = []
for col in df.columns:
    if df[col].nunique(dropna=False) == 1:
        constant_columns.append(col)

print("Columns where every row is the same:", constant_columns)

# drop constant columns
df = df.drop(columns=constant_columns)

# drop rows where all columns are NaN
#df = df.dropna(axis=0, how='all')
# Out:
# Columns where every row is the same: ['ColorGradeGlobalHue', 'ColorGradeGlobalSat', 'ColorGradeGlobalLum', 'ColorGradeShadowHue', 'ColorGradeShadowSat', 'ColorGradeHighlightHue', 'ColorGradeHighlightSat']

# %%
# Print out the number of images with edits for each particular column
edit_counts = []
for col in df.columns:
    num_edits = df[col].notnull().sum()
    edit_counts.append((col, num_edits))

# Sort ascending by num_edits
edit_counts.sort(key=lambda x: x[1])

for col, num_edits in edit_counts:
    print(f"{col}: {num_edits} images with edits")
# Out:
# RedSaturation: 1 images with edits
# GreenSaturation: 1 images with edits
# BlueSaturation: 1 images with edits
# HueAdjustmentAqua: 2 images with edits
# rating: 5 images with edits
# LuminanceAdjustmentPurple: 10 images with edits
# LuminanceAdjustmentMagenta: 18 images with edits
# SaturationAdjustmentAqua: 56 images with edits
# HueAdjustmentPurple: 165 images with edits
# HueAdjustmentGreen: 180 images with edits
# HueAdjustmentYellow: 185 images with edits
# SaturationAdjustmentGreen: 189 images with edits
# SaturationAdjustmentMagenta: 190 images with edits
# SaturationAdjustmentPurple: 197 images with edits
# LuminanceAdjustmentAqua: 207 images with edits
# LuminanceAdjustmentBlue: 210 images with edits
# SaturationAdjustmentYellow: 212 images with edits
# BlueHue: 280 images with edits
# SaturationAdjustmentBlue: 283 images with edits
# HueAdjustmentMagenta: 304 images with edits
# HueAdjustmentOrange: 341 images with edits
# SaturationAdjustmentOrange: 496 images with edits
# SaturationAdjustmentRed: 2025 images with edits
# HueAdjustmentBlue: 2072 images with edits
# HueAdjustmentRed: 2470 images with edits
# LuminanceAdjustmentGreen: 2940 images with edits
# LuminanceAdjustmentRed: 3121 images with edits
# IncrementalTemperature: 3228 images with edits
# IncrementalTint: 3228 images with edits
# ShadowTint: 3229 images with edits
# Texture: 3275 images with edits
# LuminanceAdjustmentYellow: 3277 images with edits
# LuminanceAdjustmentOrange: 3301 images with edits
# RedHue: 3317 images with edits
# Dehaze: 3322 images with edits
# GreenHue: 3322 images with edits
# Clarity2012: 3337 images with edits
# camera_model: 3448 images with edits
# lens: 3448 images with edits
# aperture: 3448 images with edits
# focal_length: 3448 images with edits
# iso: 3448 images with edits
# shutter_speed: 3448 images with edits
# image_id: 3449 images with edits
# filename: 3449 images with edits
# folder: 3449 images with edits
# file_path: 3449 images with edits
# capture_time: 3449 images with edits
# pick: 3449 images with edits
# Exposure2012: 3449 images with edits
# Contrast2012: 3449 images with edits
# Highlights2012: 3449 images with edits
# Shadows2012: 3449 images with edits
# Whites2012: 3449 images with edits
# Blacks2012: 3449 images with edits
# Vibrance: 3449 images with edits
# Saturation: 3449 images with edits
# ColorGradeBlending: 3449 images with edits
# ColorGradeShadowLum: 3449 images with edits
# ColorGradeMidtoneHue: 3449 images with edits
# ColorGradeMidtoneSat: 3449 images with edits
# ColorGradeMidtoneLum: 3449 images with edits
# ColorGradeHighlightLum: 3449 images with edits

# %%
# name the number images which have edits to a particular column

edit_counts = []
for col in df.columns:
    # Count number of images (rows) with a non-null (not NaN) and non-zero value in this column
    num_edits = ((df[col].notnull()) & (df[col] != 0)).sum()
    edit_counts.append((col, num_edits))

# Sort descending by num_edits
edit_counts.sort(key=lambda x: x[1], reverse=False)

for col, num_edits in edit_counts:
    print(f"{col}: {num_edits} images with edits (not null and not zero)")
# Out:
# RedSaturation: 1 images with edits (not null and not zero)
# GreenSaturation: 1 images with edits (not null and not zero)
# BlueSaturation: 1 images with edits (not null and not zero)
# HueAdjustmentAqua: 2 images with edits (not null and not zero)
# rating: 5 images with edits (not null and not zero)
# LuminanceAdjustmentPurple: 10 images with edits (not null and not zero)
# LuminanceAdjustmentMagenta: 18 images with edits (not null and not zero)
# ColorGradeHighlightLum: 38 images with edits (not null and not zero)
# SaturationAdjustmentAqua: 56 images with edits (not null and not zero)
# HueAdjustmentPurple: 165 images with edits (not null and not zero)
# HueAdjustmentGreen: 180 images with edits (not null and not zero)
# HueAdjustmentYellow: 185 images with edits (not null and not zero)
# SaturationAdjustmentGreen: 189 images with edits (not null and not zero)
# SaturationAdjustmentMagenta: 190 images with edits (not null and not zero)
# SaturationAdjustmentPurple: 197 images with edits (not null and not zero)
# ColorGradeShadowLum: 199 images with edits (not null and not zero)
# LuminanceAdjustmentAqua: 207 images with edits (not null and not zero)
# LuminanceAdjustmentBlue: 210 images with edits (not null and not zero)
# SaturationAdjustmentYellow: 212 images with edits (not null and not zero)
# ColorGradeMidtoneLum: 217 images with edits (not null and not zero)
# BlueHue: 280 images with edits (not null and not zero)
# SaturationAdjustmentBlue: 283 images with edits (not null and not zero)
# HueAdjustmentMagenta: 304 images with edits (not null and not zero)
# HueAdjustmentOrange: 341 images with edits (not null and not zero)
# SaturationAdjustmentOrange: 496 images with edits (not null and not zero)
# pick: 533 images with edits (not null and not zero)
# ColorGradeMidtoneSat: 1387 images with edits (not null and not zero)
# ColorGradeMidtoneHue: 1432 images with edits (not null and not zero)
# SaturationAdjustmentRed: 2025 images with edits (not null and not zero)
# HueAdjustmentBlue: 2072 images with edits (not null and not zero)
# HueAdjustmentRed: 2470 images with edits (not null and not zero)
# Vibrance: 2623 images with edits (not null and not zero)
# Saturation: 2652 images with edits (not null and not zero)
# Contrast2012: 2939 images with edits (not null and not zero)
# LuminanceAdjustmentGreen: 2940 images with edits (not null and not zero)
# IncrementalTint: 3078 images with edits (not null and not zero)
# IncrementalTemperature: 3088 images with edits (not null and not zero)
# LuminanceAdjustmentRed: 3121 images with edits (not null and not zero)
# ShadowTint: 3229 images with edits (not null and not zero)
# Texture: 3275 images with edits (not null and not zero)
# LuminanceAdjustmentYellow: 3277 images with edits (not null and not zero)
# LuminanceAdjustmentOrange: 3301 images with edits (not null and not zero)
# aperture: 3313 images with edits (not null and not zero)
# RedHue: 3317 images with edits (not null and not zero)
# Dehaze: 3322 images with edits (not null and not zero)
# GreenHue: 3322 images with edits (not null and not zero)
# Clarity2012: 3336 images with edits (not null and not zero)
# Exposure2012: 3396 images with edits (not null and not zero)
# Blacks2012: 3419 images with edits (not null and not zero)
# Whites2012: 3422 images with edits (not null and not zero)
# Highlights2012: 3423 images with edits (not null and not zero)
# Shadows2012: 3423 images with edits (not null and not zero)
# ColorGradeBlending: 3447 images with edits (not null and not zero)
# camera_model: 3448 images with edits (not null and not zero)
# lens: 3448 images with edits (not null and not zero)
# focal_length: 3448 images with edits (not null and not zero)
# iso: 3448 images with edits (not null and not zero)
# shutter_speed: 3448 images with edits (not null and not zero)
# image_id: 3449 images with edits (not null and not zero)
# filename: 3449 images with edits (not null and not zero)
# folder: 3449 images with edits (not null and not zero)
# file_path: 3449 images with edits (not null and not zero)
# capture_time: 3449 images with edits (not null and not zero)

# %%
# drop where camera model is nan
df = df[df['camera_model'].notna()]

# %%
# Exclude any rows where the filename ends with .dng (case-insensitive)
df = df[~df['filename'].str.lower().str.endswith('.dng')]

# %%
# Identify rows where all four columns are 0 (including cases where they may be missing)
zero_adjust_cols = ['Highlights2012', 'Shadows2012', 'Whites2012', 'Blacks2012']
# Make sure all required columns exist before proceeding
existing_cols = [col for col in zero_adjust_cols]
if len(existing_cols) == 4:
    all_zero_mask = (df[zero_adjust_cols] == 0).all(axis=1)
    num_rows_to_drop = all_zero_mask.sum()
    print(f"Rows with all tone sliders (Highlights2012/Shadows2012/Whites2012/Blacks2012) == 0: {num_rows_to_drop}")
    df = df[~all_zero_mask]
# Out:
# Rows with all tone sliders (Highlights2012/Shadows2012/Whites2012/Blacks2012) == 0: 19

# %%
df
# Out:
#       image_id      filename            folder                     file_path  \
# 1       618282  DSC08454.ARW  2025/2025-12-13/  2025/2025-12-13/DSC08454.ARW
# 2       614396  DSC08454.ARW  2025/2025-12-13/  2025/2025-12-13/DSC08454.ARW
# 3       625919  DSC08445.ARW  2025/2025-12-13/  2025/2025-12-13/DSC08445.ARW
# 4       625291  DSC08445.ARW  2025/2025-12-13/  2025/2025-12-13/DSC08445.ARW
# 5       625126  DSC08445.ARW  2025/2025-12-13/  2025/2025-12-13/DSC08445.ARW
# ...        ...           ...               ...                           ...
# 3444       295  IMG_8054.CR2  2024/2024-12-29/  2024/2024-12-29/IMG_8054.CR2
# 3445       294  IMG_8053.CR2  2024/2024-12-29/  2024/2024-12-29/IMG_8053.CR2
# 3446      7485  IMG_8052.CR2  2024/2024-12-29/  2024/2024-12-29/IMG_8052.CR2
# 3447      7484  IMG_8051.CR2  2024/2024-12-29/  2024/2024-12-29/IMG_8051.CR2
# 3448       288  IMG_8047.CR2  2024/2024-12-21/  2024/2024-12-21/IMG_8047.CR2
#
#                  capture_time  rating  pick    camera_model  \
# 1     2025-12-13T11:49:12.471     NaN   0.0       ILCE-6700
# 2     2025-12-13T11:49:12.471     NaN   0.0       ILCE-6700
# 3     2025-12-13T11:44:00.734     NaN   0.0       ILCE-6700
# 4     2025-12-13T11:44:00.734     NaN   0.0       ILCE-6700
# 5     2025-12-13T11:44:00.734     NaN   0.0       ILCE-6700
# ...                       ...     ...   ...             ...
# 3444   2024-12-29T16:05:59.29     NaN   0.0  Canon EOS 600D
# 3445   2024-12-29T15:59:25.59     NaN   0.0  Canon EOS 600D
# 3446   2024-12-29T15:59:24.03     NaN   0.0  Canon EOS 600D
# 3447   2024-12-29T15:59:23.05     NaN   0.0  Canon EOS 600D
# 3448   2024-12-21T18:46:39.56     NaN   0.0  Canon EOS 600D
#
#                                        lens  aperture  ...  \
# 1     18-50mm F2.8 DC DN | Contemporary 021  2.970854  ...
# 2     18-50mm F2.8 DC DN | Contemporary 021  2.970854  ...
# 3     18-50mm F2.8 DC DN | Contemporary 021  2.970854  ...
# 4     18-50mm F2.8 DC DN | Contemporary 021  2.970854  ...
# 5     18-50mm F2.8 DC DN | Contemporary 021  2.970854  ...
# ...                                     ...       ...  ...
# 3444            EF-S18-55mm f/3.5-5.6 IS II  4.970854  ...
# 3445            EF-S18-55mm f/3.5-5.6 IS II  4.970854  ...
# 3446            EF-S18-55mm f/3.5-5.6 IS II  4.970854  ...
# 3447            EF-S18-55mm f/3.5-5.6 IS II  4.970854  ...
# 3448            EF-S18-55mm f/3.5-5.6 IS II  4.970854  ...
#
#       ColorGradeMidtoneSat  ColorGradeMidtoneLum  ColorGradeHighlightLum  \
# 1                        0                     0                       0
# 2                        0                     0                       0
# 3                       17                    15                       0
# 4                        0                     0                       0
# 5                        0                     0                       0
# ...                    ...                   ...                     ...
# 3444                     0                     0                       0
# 3445                     0                     0                       0
# 3446                     0                     0                       0
# 3447                     0                     0                       0
# 3448                     0                     0                       0
#
#       ShadowTint  RedHue  RedSaturation  GreenHue  GreenSaturation  BlueHue  \
# 1            NaN     NaN            NaN       NaN              NaN      NaN
# 2           -3.0    23.0            NaN      73.0              NaN      NaN
# 3          -11.0    27.0            NaN      72.0              NaN    -13.0
# 4           -7.0    24.0            NaN      77.0              NaN      NaN
# 5          -14.0    26.0            NaN      75.0              NaN      NaN
# ...          ...     ...            ...       ...              ...      ...
# 3444         NaN   -12.0            NaN      39.0              NaN     -5.0
# 3445       -25.0    23.0            NaN      67.0              NaN      NaN
# 3446       -25.0    23.0            NaN      67.0              NaN      NaN
# 3447       -25.0    23.0            NaN      67.0              NaN      NaN
# 3448         NaN    22.0            NaN      43.0              NaN     -8.0
#
#       BlueSaturation
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# ...              ...
# 3444             NaN
# 3445             NaN
# 3446             NaN
# 3447             NaN
# 3448             NaN
#
# [3386 rows x 63 columns]

# %%
output_parquet_path = "processed_images.parquet"
df.to_parquet(output_parquet_path, index=False)
print(f"Saved processed DataFrame to {output_parquet_path}")
# Out:
# Saved processed DataFrame to processed_images.parquet
